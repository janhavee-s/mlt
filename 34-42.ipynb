# %%
# Task 34: Lasso Regression

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

df = pd.read_csv("insurance.csv")

le = LabelEncoder()
for col in ['sex', 'smoker', 'region']:
    df[col] = le.fit_transform(df[col])

X = df.drop('charges', axis=1)
y = df['charges']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

model = Lasso(alpha=1.0, random_state=42)
model.fit(X_train, y_train)

pred = model.predict(X_test)

print("MSE:", mean_squared_error(y_test, pred))
# Out:
# MSE: 35174969.2852089

# %%
# Task 35: Compare Linear, Ridge, Lasso

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error

df = pd.read_csv("insurance.csv")

le = LabelEncoder()
for col in ['sex', 'smoker', 'region']:
    df[col] = le.fit_transform(df[col])

X = df.drop('charges', axis=1)
y = df['charges']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

lin = LinearRegression()
ridge = Ridge(alpha=1.0, random_state=42)
lasso = Lasso(alpha=1.0, random_state=42)

lin.fit(X_train, y_train)
ridge.fit(X_train, y_train)
lasso.fit(X_train, y_train)

print("Linear MSE:", mean_squared_error(y_test, lin.predict(X_test)))
print("Ridge MSE:", mean_squared_error(y_test, ridge.predict(X_test)))
print("Lasso MSE:", mean_squared_error(y_test, lasso.predict(X_test)))
# Out:
# Linear MSE: 35174149.327053055
# Ridge MSE: 35212846.093521826
# Lasso MSE: 35174969.2852089

# %%
# Task 36: Cross Validation MSE

import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
import numpy as np

df = pd.read_csv("insurance.csv")

le = LabelEncoder()
for col in ['sex', 'smoker', 'region']:
    df[col] = le.fit_transform(df[col])

X = df.drop('charges', axis=1)
y = df['charges']

model = LinearRegression()

mse_scores = -cross_val_score(model, X, y, cv=5, scoring='neg_mean_squared_error')

print("Cross-Validation MSE:", np.mean(mse_scores))
# Out:
# Cross-Validation MSE: 36862396.258872904

# %%
# Task 37: Validation vs Cross Validation

import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

df = pd.read_csv("insurance.csv")

le = LabelEncoder()
for col in ['sex', 'smoker', 'region']:
    df[col] = le.fit_transform(df[col])

X = df.drop('charges', axis=1)
y = df['charges']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

model = LinearRegression()
model.fit(X_train, y_train)

pred = model.predict(X_test)

val_mse = mean_squared_error(y_test, pred)

# Cross-validation
cv_mse = -cross_val_score(model, X, y, cv=5, scoring='neg_mean_squared_error').mean()

print("Validation MSE:", val_mse)
print("Cross-Validation MSE:", cv_mse)
# Out:
# Validation MSE: 35174149.327053055
# Cross-Validation MSE: 36862396.258872904

# %%
# Task 38: Best Model Selection

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error

df = pd.read_csv("insurance.csv")

le = LabelEncoder()
for col in ['sex', 'smoker', 'region']:
    df[col] = le.fit_transform(df[col])

X = df.drop('charges', axis=1)
y = df['charges']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

models = {
    "Linear": LinearRegression(),
    "Ridge": Ridge(alpha=1.0, random_state=42),
    "Lasso": Lasso(alpha=1.0, random_state=42)
}

for name, model in models.items():
    model.fit(X_train, y_train)
    mse = mean_squared_error(y_test, model.predict(X_test))
    print(f"{name} MSE: {mse}")
# Out:
# Linear MSE: 35174149.327053055
# Ridge MSE: 35212846.093521826
# Lasso MSE: 35174969.2852089

# %%
# Task 39: Alpha Tuning

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

df = pd.read_csv("insurance.csv")

le = LabelEncoder()
for col in ['sex', 'smoker', 'region']:
    df[col] = le.fit_transform(df[col])

X = df.drop('charges', axis=1)
y = df['charges']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

for alpha in [0.01, 0.1, 1, 10, 100]:
    model = Ridge(alpha=alpha, random_state=42)
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    print(f"Alpha={alpha}, MSE={mean_squared_error(y_test, pred)}")
# Out:
# Alpha=0.01, MSE=35174505.47070449
# Alpha=0.1, MSE=35177739.10648192
# Alpha=1, MSE=35212846.093521826
# Alpha=10, MSE=35808736.739218146
# Alpha=100, MSE=50338818.82420256

# %%
# Task 41: Ridge vs Lasso Coefficients

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import Ridge, Lasso

df = pd.read_csv("insurance.csv")

le = LabelEncoder()
for col in ['sex', 'smoker', 'region']:
    df[col] = le.fit_transform(df[col])

X = df.drop('charges', axis=1)
y = df['charges']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

ridge = Ridge(alpha=1.0, random_state=42)
lasso = Lasso(alpha=1.0, random_state=42)

ridge.fit(X_train, y_train)
lasso.fit(X_train, y_train)

print("Ridge Coefficients:", ridge.coef_)
print("Lasso Coefficients:", lasso.coef_)
# Out:
# Ridge Coefficients: [  259.70931436    54.19161087   337.08057518   428.52040808
#  23478.37218837  -299.17280026]
# Lasso Coefficients: [  259.86383816    44.47117818   337.00731194   426.93243166
#  23616.67919216  -298.2744723 ]

# %%
# Task 42: Linear vs Polynomial Final

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

df = pd.read_csv("insurance.csv")

le = LabelEncoder()
for col in ['sex', 'smoker', 'region']:
    df[col] = le.fit_transform(df[col])

X = df.drop('charges', axis=1)
y = df['charges']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Linear
lin = LinearRegression()
lin.fit(X_train, y_train)
pred1 = lin.predict(X_test)

# Polynomial
poly = PolynomialFeatures(degree=2)
X_train_p = poly.fit_transform(X_train)
X_test_p = poly.transform(X_test)

lin2 = LinearRegression()
lin2.fit(X_train_p, y_train)
pred2 = lin2.predict(X_test_p)

print("Linear MSE:", mean_squared_error(y_test, pred1))
print("Polynomial MSE:", mean_squared_error(y_test, pred2))
# Out:
# Linear MSE: 35174149.327053055
# Polynomial MSE: 21676723.589904815
